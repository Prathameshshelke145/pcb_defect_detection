# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip /content/drive/MyDrive/dataset-pcb.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/dataset-pcb.zip
#    creating: /content/dataset-pcb/
#    creating: /content/dataset-pcb/images/
#    creating: /content/dataset-pcb/images/train/
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_06.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_07.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_08.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_10.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_11.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_12.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17752, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 17752 (delta 72), reused 39 (delta 39), pack-reused 17635 (from 3)
# Receiving objects: 100% (17752/17752), 17.15 MiB | 29.07 MiB/s, done.
# Resolving deltas: 100% (12054/12054), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.0 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 300 --data dataset.yaml --weights yolov5s.pt --cache --name pcb_unmounted
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-12-07 10:34:41.103535: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765103681.124900    1731 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !zip -r /content/drive/MyDrive/datasets/runs-pcb.zip /content/yolov5/runs
# Out:
# zip I/O error: No such file or directory
# zip error: Could not create output file (/content/drive/MyDrive/datasets/runs-pcb.zip)

# %%
# !python val.py --weights runs/train/pcb_1st2/weights/best.pt --data dataset.yaml
# Out:
# val: data=dataset.yaml, weights=['runs/train/pcb_1st2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-433-ga1019635 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/dataset-pcb/labels/val.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:13<00:00,  2.64s/it]
#                    all        138        590      0.929       0.91      0.933      0.465
#           missing_hole        138         94      0.772          1       0.96      0.525
# ...

# %%
# !python detect.py --source /content/test/11.JPG  --weights runs/train/pcb_1st2/weights/best.pt
# Out:
# detect: weights=['runs/train/pcb_1st2/weights/best.pt'], source=/content/test/11.JPG, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-433-ga1019635 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test/11.JPG: 640x640 (no detections), 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 16.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Creates a folder inside your Drive for YOLOv5 backup
# !mkdir -p /content/drive/MyDrive/yolov5_backup

# %%
# Copy YOLOv5 code, trained model, and outputs to Google Drive
# !cp -r /content/yolov5 /content/drive/MyDrive/yolov5_backup/
# !cp -r /content/yolov5/runs /content/drive/MyDrive/yolov5_backup/

# %%
# !ls -R /content/drive/MyDrive/yolov5_backup | head -n 50
# Out:
# /content/drive/MyDrive/yolov5_backup:
# runs
# yolov5
#
# /content/drive/MyDrive/yolov5_backup/runs:
# detect
# train
# val
#
# /content/drive/MyDrive/yolov5_backup/runs/detect:
# exp
# exp2
# exp3
# exp4
# exp5
# exp6
# exp7
# exp8
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp:
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp2:
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp3:
# 01.JPG
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp4:
# 04.JPG
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp5:
# 05.JPG
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp6:
# 06.JPG
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp7:
#
# /content/drive/MyDrive/yolov5_backup/runs/detect/exp8:
# 11.JPG
#
# /content/drive/MyDrive/yolov5_backup/runs/train:
# pcb_1st
# pcb_1st2
#
# /content/drive/MyDrive/yolov5_backup/runs/train/pcb_1st:
# confusion_matrix.png
# events.out.tfevents.1759685734.3bf2edae720a.3915.0
# F1_curve.png
# hyp.yaml
# ...

# %%
# Zip yolov5 code, runs folder, and best.pt if present
# !zip -r /content/yolov5_full_backup.zip /content/yolov5 /content/runs
# Out:
# 	zip warning: name not matched: /content/runs
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/data/ (stored 0%)
#   adding: content/yolov5/data/VisDrone.yaml (deflated 59%)
#   adding: content/yolov5/data/images/ (stored 0%)
#   adding: content/yolov5/data/images/zidane.jpg (deflated 0%)
#   adding: content/yolov5/data/images/bus.jpg (deflated 1%)
#   adding: content/yolov5/data/scripts/ (stored 0%)
#   adding: content/yolov5/data/scripts/get_coco128.sh (deflated 38%)
#   adding: content/yolov5/data/scripts/get_imagenet100.sh (deflated 43%)
#   adding: content/yolov5/data/scripts/download_weights.sh (deflated 45%)
#   adding: content/yolov5/data/scripts/get_imagenet1000.sh (deflated 43%)
#   adding: content/yolov5/data/scripts/get_coco.sh (deflated 60%)
#   adding: content/yolov5/data/scripts/get_imagenet10.sh (deflated 43%)
#   adding: content/yolov5/data/scripts/get_imagenet.sh (deflated 54%)
#   adding: content/yolov5/data/coco128.yaml (deflated 47%)
# ...

# %%
from google.colab import files
files.download('/content/yolov5_full_backup.zip')

# %%
model =load_model('/content/yolov5/runs/train/pcb_1st/weights/best.pt')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52fcf98f-eb74-4c1e-bcd7-13fd7b580c61" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52fcf98f-eb74-4c1e-bcd7-13fd7b580c61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q yolov5_full_backup.zip -d /content/

# %%
# %cd "/content/content/yolov5"
# Out:
# /content/content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.4 MB/s eta 0:00:00
# ...

# %%
model_path = "/content/content/yolov5/runs/train/pcb_1st2/weights/best.pt"

# %%
image_path = "/content/06.JPG"

# %%
# !python detect.py --weights $model_path --source $image_path --conf 0.4 --save-txt --save-conf
# Out:
# detect: weights=['/content/content/yolov5/runs/train/pcb_1st2/weights/best.pt'], source=/content/06.JPG, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-433-ga1019635 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/06.JPG: 544x640 (no detections), 31.6ms
# Speed: 0.6ms pre-process, 31.6ms inference, 109.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10
# 0 labels saved to runs/detect/exp10/labels
